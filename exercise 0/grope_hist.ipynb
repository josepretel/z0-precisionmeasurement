# %% [markdown]
# ### Generating the  histogramms for the grope test samples

# %%
import numpy as np
import matplotlib.pyplot as plt

# read in the data
h=np.loadtxt("Hadron.txt")
e=np.loadtxt("Electron.txt")
m=np.loadtxt("Muon.txt")
t=np.loadtxt("Tau.txt")
h=h.transpose();
e=e.transpose();
m=m.transpose();
t=t.transpose();

# make the histograms
plt.hist(h[2],bins=np.arange(0, 300, 5),label=r'$Z^0$ $\to$ hadrons')
plt.hist(e[2],bins=np.arange(0, 300, 5),label=r'$Z^0$ $\to$ $e^+e^-$')
plt.hist(m[3],bins=np.arange(0, 300, 5),label=r'$Z^0$ $\to$ $\mu^+\mu^-$')
plt.hist(t[3],bins=np.arange(0, 300, 5),label=r'$Z^0$ $\to$ $\tau^+\tau^-$')
plt.title(r'PCHARGED: histogram of scalar sum of charged momenta')
plt.legend()
plt.xlabel(r'total scalar momentum [GeV]')
plt.show()

plt.hist(h[3],bins=np.arange(0, 60, 1),label=r'$Z^0$ $\to$ hadrons')
plt.hist(e[3],bins=np.arange(0, 60, 1),label=r'$Z^0$ $\to$ $e^+e^-$')
plt.hist(m[2],bins=np.arange(0, 60, 1),label=r'$Z^0$ $\to$ $\mu^+\mu^-$')
plt.hist(t[2],bins=np.arange(0, 60, 1),label=r'$Z^0$ $\to$ $\tau^+\tau^-$')
plt.title(r'NCHARGED: histogram of charged particles multiplicity')
plt.legend()
plt.xlabel(r'Multiplicity')
plt.show()

plt.hist(h[4],bins=np.arange(0, 100, 2),label=r'$Z^0$ $\to$ hadrons')
plt.hist(e[4],bins=np.arange(0, 100, 2),label=r'$Z^0$ $\to$ $e^+e^-$')
plt.hist(m[4],bins=np.arange(0, 100, 2),label=r'$Z^0$ $\to$ $\mu^+\mu^-$')
plt.hist(t[4],bins=np.arange(0, 100, 2),label=r'$Z^0$ $\to$ $\tau^+\tau^-$')
plt.title(r'E_ECAL: histogram of total energy in the Ecal')
plt.legend()
plt.xlabel(r'total energy [GeV]')
plt.show()

plt.hist(h[5],bins=np.arange(0, 210, 4),label=r'$Z^0$ $\to$ hadrons')
plt.hist(e[5],bins=np.arange(0, 210, 4),label=r'$Z^0$ $\to$ $e^+e^-$')
plt.hist(m[5],bins=np.arange(0, 210, 4),label=r'$Z^0$ $\to$ $\mu^+\mu^-$')
plt.hist(t[5],bins=np.arange(0, 210, 4),label=r'$Z^0$ $\to$ $\tau^+\tau^-$')
plt.title(r'E_HCAL: histogram of total energy in the Hcal')
plt.legend()
plt.xlabel(r'total energy [GeV]')
plt.show()
