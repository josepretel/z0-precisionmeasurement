# %%
import matplotlib.pyplot as plt

plt.style.use('bmh') 
plt.rcParams['figure.figsize'] = [10, 5]

e = [0,84.4,92.2,0,78,5,83.8,0,0,71,0,71.6,71.3,74.4,0,83.2,47.9,65.1,82.5,0,0]
h = [54.8, 50, 32, 53.3, 13.9, 40.4, 43.3, 3.2, 293.1, 39.8, 72, 66.2, 49.7,53.8,13.2,60.2,18.9,60.9,48.7,59.8]
t = [43.8,31.4,43,37.6,55,33.9,0,44.7,2,67,99.3,45.8,0,30.4,41.1,26.9,64.6,44.9,25,29.8]
m = [84.7,89.5,98.2,105.1,84.1,88.1,119.1,87.3,87.7,87,93,80.9,92.3,89,93.4,94.3,86.5,90.3,83.2,96.1]
plt.hist(e, bins=8, color='purple', edgecolor='k', lw=2,label='Electron')
plt.hist(h, bins=8, color='white', edgecolor='k', lw=2, label='Hadron')
plt.hist(t, bins=8, color= 'cyan', edgecolor='k', lw=2, label= 'tau')
plt.hist(m, bins=8, color='yellow', edgecolor='k',lw=2, label= 'muon')
plt.xlabel('Sump')
plt.ylabel('Ne')
plt.title('Pcharged')
plt.legend()
plt.show()

# %%
plt.hist(e, bins=8, color='purple', edgecolor='k', lw=2,label='Electron',range=(80, 125))
plt.hist(h, bins=8, color='white', edgecolor='k', lw=2, label='Hadron',range=(80, 125))
plt.hist(t, bins=8, color= 'cyan', edgecolor='k', lw=2, label= 'tau', range=(80, 125))
plt.hist(m, bins=8, color='yellow', edgecolor='k',lw=2, label= 'muon', range=(80, 125))
plt.xlabel('Sump')
plt.ylabel('Ne')
plt.title('Pcharged')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

e = [3,7,2,7,3,2,5,0,2,6,2,3,2,14,2,6,5,2,4,2]
h = [52,28,24,36,28,39,21,30,22,34,39,20,25,25,53,30,37,23,27,9]
t = [4,2,2,5,2,2,3,14,6,6,2,4,8,2,2,2,4,13,2,2]
m = [6,2,2,2,2,2,2,4,2,2,2,2,4,2,2,7,2,2,2,2]
plt.hist(e, bins=8, color='purple', edgecolor='k', lw=2,label='Electron')
plt.hist(h, bins=8, color='white', edgecolor='k', lw=2, label='Hadron')
plt.hist(t, bins=8, color= 'cyan', edgecolor='k', lw=2, label= 'tau')
plt.hist(m, bins=8, color='yellow', edgecolor='k',lw=2, label= 'muon')
plt.xlabel('Ctrk_N')
plt.ylabel('Ne')
plt.title('Ncharged')
plt.legend()
plt.show()

# %%
plt.hist(e, bins=8, color='purple', edgecolor='k', lw=2,label='Electron',range=(15, 60))
plt.hist(h, bins=8, color='white', edgecolor='k', lw=2, label='Hadron',range=(15, 60))
plt.hist(t, bins=8, color= 'cyan', edgecolor='k', lw=2, label= 'tau', range=(15, 60))
plt.hist(m, bins=8, color='yellow', edgecolor='k',lw=2, label= 'muon', range=(15, 60))
plt.xlabel('Ctrk_N')
plt.ylabel('Ne')
plt.title('Ncharged')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

e = [92,89.1,89.5,67.9,90.3,93.5,75.3,84.1,91.6,95.3,92.2,94.2,88.5,83.8,91.2,90.3,92.5,90.3,91.1,90.1]
h = [39.7, 55.7, 46.7, 33.2, 58.4, 58.8, 50.8, 37.2, 52.9,50.7,41.4,23.8,37.8,53.2,51.5,37.8,58.8,53.4,57,55.6]
t = [8.2, 36.1, 31.7, 43, 49.7, 52, 31.1, 35.7, 90.8, 45, 16.6, 40.1,70.8,21.7,40.6,51.8,29.8,37.5,44.9,36.5]
m = [1.4, 1.6, 2.6, 1.8, 5.4, 1.5, 2.1, 5.3, 3, 1.8, 1.3, 3.1, 1.7,3.1,1.7,1.3,6.2,2.5,1.8,1.8,]
plt.hist(e, bins=8, color='purple', edgecolor='k', lw=2,label='Electron')
plt.hist(h, bins=8, color='white', edgecolor='k', lw=2, label='Hadron')
plt.hist(t, bins=8, color= 'cyan', edgecolor='k', lw=2, label= 'tau')
plt.hist(m, bins=8, color='yellow', edgecolor='k',lw=2, label= 'muon')
plt.xlabel('SumE')
plt.ylabel('Ne')
plt.title('E_ecal')
plt.legend()
plt.show()

# %%
plt.hist(e, bins=8, color='purple', edgecolor='k', lw=2,label='Electron',range=(80, 100))
plt.hist(h, bins=8, color='white', edgecolor='k', lw=2, label='Hadron',range=(80, 100))
plt.hist(t, bins=8, color= 'cyan', edgecolor='k', lw=2, label= 'tau', range=(80, 100))
plt.hist(m, bins=8, color='yellow', edgecolor='k',lw=2, label= 'muon', range=(80, 100))
plt.xlabel('SumE')
plt.ylabel('Ne')
plt.title('E_ecal')
plt.legend()
plt.show()

# %%
plt.hist(e, bins=8, color='purple', edgecolor='k', lw=2,label='Electron',range=(10, 50))
plt.hist(h, bins=8, color='white', edgecolor='k', lw=2, label='Hadron',range=(10, 50))
plt.hist(t, bins=8, color= 'cyan', edgecolor='k', lw=2, label= 'tau', range=(10, 50))
plt.hist(m, bins=8, color='yellow', edgecolor='k',lw=2, label= 'muon', range=(10, 50))
plt.xlabel('SumE')
plt.ylabel('Ne')
plt.title('E_ecal')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

e = [0.2,0.2,0.2,0,0.3,0.9,0.8,0.8,1.8,1.4,0,0.7,0.3,0.3,0.3,0.3,0,0.3,2.2,6.1]
h = [15.8,11.9,8.3,16.3,5.5,0.6,203.9,3.3,15.7,13.5,25,15.9,48.7,17.7,6,84.6,9,28.4,9.5,23.3]
t = [2,0.2,2.4,0.6,36.8,13.6,0.3,3.3,0.7,33.6,16.8,38.2,0,7.5,2.6,0,9.2,2.2,4.1,23.4]
m = [2.4,13.4,9.9,6.6,13.8,3.5,6.2,30.3,9.3,10,2.6,4.7,5.5,5.3,1.8,3.9,44.7,18.8,4.9,10.7]
plt.hist(e, bins=8, color='purple', edgecolor='k', lw=2,label='Electron')
plt.hist(h, bins=8, color='white', edgecolor='k', lw=2, label='Hadron')
plt.hist(t, bins=8, color= 'cyan', edgecolor='k', lw=2, label= 'tau')
plt.hist(m, bins=8, color='yellow', edgecolor='k',lw=2, label= 'muon')
plt.xlabel('P_hcal')
plt.ylabel('Ne')
plt.title('E_hcal')
plt.legend()
plt.show()
