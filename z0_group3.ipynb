# %% [markdown]
# #### Houda Semmoumy and Vishali Vishali

# %%
import uproot
import awkward as ak
import mplhep
# %matplotlib inline 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading Root files and Plotting the graphs

# %% [markdown]
# ###### Electrons

# %%
path_data = 'Data/'
#path_mc = 'samples/data'

### Open the file introducing file path
file = uproot.open(path_data+'ee.root')
ttree_name = 'myTTree'

### Print list of 'branches' of the TTree (i.e. list of variable names)
file[ttree_name].keys()

## Load branches
branches_e = file[ttree_name].arrays()

## Define an numpy array for 'Pcharged'
var = 'Pcharged'
var1 = 'Ncharged'
var2 = 'E_ecal'
var3 = 'E_hcal'
pchar_e = ak.to_numpy(branches_e[var]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions
nchar_e = ak.to_numpy(branches_e[var1]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions
E_e_e = ak.to_numpy(branches_e[var2]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions
E_h_e = ak.to_numpy(branches_e[var3]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions

print(f"Array of type '{type(pchar_e)}' defined for '{var}':\n{pchar_e}")
print(pchar_e.max())
print(f"Array of type '{type(nchar_e)}' defined for '{var1}':\n{nchar_e}")
print(nchar_e.max())
print(f"Array of type '{type(E_e_e)}' defined for '{var2}':\n{E_e_e}")
print(E_e_e.max())
print(f"Array of type '{type(E_h_e)}' defined for '{var3}':\n{E_h_e}")
print(E_h_e.max())
# Out:
# Array of type '<class 'numpy.ndarray'>' defined for 'Pcharged':
# [81.32794  71.334854  0.       ... 73.69003  81.64756  80.798645]
# 55299.59
# Array of type '<class 'numpy.ndarray'>' defined for 'Ncharged':
# [2. 2. 0. ... 2. 2. 2.]
# 9.0
# Array of type '<class 'numpy.ndarray'>' defined for 'E_ecal':
# [88.92962  90.303406 89.63274  ... 96.30155  92.580894 89.81569 ]
# 124.320595
# Array of type '<class 'numpy.ndarray'>' defined for 'E_hcal':
# [0.   0.   3.19 ... 0.   0.   0.  ]
# 82.450005

# %% [markdown]
# ###### Taus

# %%
path_data = 'Data/'
#path_mc = 'samples/data'

### Open the file introducing file path
file = uproot.open(path_data+'tt.root')
ttree_name = 'myTTree'

### Print list of 'branches' of the TTree (i.e. list of variable names)
file[ttree_name].keys()

## Load branches
branches_t = file[ttree_name].arrays()

## Define an numpy array for 'Pcharged'
var = 'Pcharged'
var1 = 'Ncharged'
var2 = 'E_ecal'
var3 = 'E_hcal'
pchar_t = ak.to_numpy(branches_t[var]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions
nchar_t = ak.to_numpy(branches_t[var1]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions
E_e_t = ak.to_numpy(branches_t[var2]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions
E_h_t = ak.to_numpy(branches_t[var3]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions

print(f"Array of type '{type(pchar_t)}' defined for '{var}':\n{pchar_t}")
print(pchar_t.max())
print(f"Array of type '{type(nchar_t)}' defined for '{var1}':\n{nchar_t}")
print(nchar_t.max())
print(f"Array of type '{type(E_e_t)}' defined for '{var2}':\n{E_e_t}")
print(E_e_t.max())
print(f"Array of type '{type(E_h_t)}' defined for '{var3}':\n{E_h_t}")
print(E_h_t.max())
# Out:
# Array of type '<class 'numpy.ndarray'>' defined for 'Pcharged':
# [25.156181 21.133148 59.023323 ... 33.127083 54.095062 17.629349]
# 719342.8
# Array of type '<class 'numpy.ndarray'>' defined for 'Ncharged':
# [2. 2. 2. ... 2. 4. 2.]
# 18.0
# Array of type '<class 'numpy.ndarray'>' defined for 'E_ecal':
# [11.392693 20.010029  6.71654  ... 38.649517 28.047812 29.352995]
# 101.030716
# Array of type '<class 'numpy.ndarray'>' defined for 'E_hcal':
# [ 2.6680105  0.4989622 15.956976  ...  0.        13.32479    1.2498789]
# 110.909996

# %% [markdown]
# ###### Muons

# %%
path_data = 'Data/'
#path_mc = 'samples/data'

### Open the file introducing file path
file = uproot.open(path_data+'mm.root')
ttree_name = 'myTTree'

### Print list of 'branches' of the TTree (i.e. list of variable names)
file[ttree_name].keys()

## Load branches
branches_m = file[ttree_name].arrays()

## Define an numpy array for 'Pcharged'
var = 'Pcharged'
var1 = 'Ncharged'
var2 = 'E_ecal'
var3 = 'E_hcal'
pchar_m = ak.to_numpy(branches_m[var]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions
nchar_m = ak.to_numpy(branches_m[var1]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions
E_e_m = ak.to_numpy(branches_m[var2]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions
E_h_m = ak.to_numpy(branches_m[var3]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions

print(f"Array of type '{type(pchar_m)}' defined for '{var}':\n{pchar_m}")
print(pchar_m.max())
print(f"Array of type '{type(nchar_m)}' defined for '{var1}':\n{nchar_m}")
print(nchar_m.max())
print(f"Array of type '{type(E_e_m)}' defined for '{var2}':\n{E_e_m}")
print(E_e_m.max())
print(f"Array of type '{type(E_h_m)}' defined for '{var3}':\n{E_h_m}")
print(E_h_m.max())
# Out:
# Array of type '<class 'numpy.ndarray'>' defined for 'Pcharged':
# [63.769375 87.26109  89.692245 ... 87.108574 94.00878  88.81888 ]
# 73101.055
# Array of type '<class 'numpy.ndarray'>' defined for 'Ncharged':
# [2. 2. 2. ... 2. 2. 2.]
# 6.0
# Array of type '<class 'numpy.ndarray'>' defined for 'E_ecal':
# [28.669762   6.565208   1.1046445 ...  3.09396    1.5415426  1.8502975]
# 87.71737
# Array of type '<class 'numpy.ndarray'>' defined for 'E_hcal':
# [3.4162734 9.029085  2.7595692 ... 2.4969237 1.9500694 0.       ]
# 98.78001

# %% [markdown]
# ###### Hadrons

# %%
path_data = 'Data/'
#path_mc = 'samples/data'

### Open the file introducing file path
file = uproot.open(path_data+'qq.root')
ttree_name = 'myTTree'

### Print list of 'branches' of the TTree (i.e. list of variable names)
file[ttree_name].keys()

## Load branches
branches_h = file[ttree_name].arrays()

## Define an numpy array for 'Pcharged'
var = 'Pcharged'
var1 = 'Ncharged'
var2 = 'E_ecal'
var3 = 'E_hcal'
pchar_h = ak.to_numpy(branches_h[var]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions
nchar_h = ak.to_numpy(branches_h[var1]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions
E_e_h = ak.to_numpy(branches_h[var2]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions
E_h_h = ak.to_numpy(branches_h[var3]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions

print(f"Array of type '{type(pchar_h)}' defined for '{var}':\n{pchar_h}")
print(pchar_h.max())
print(f"Array of type '{type(nchar_h)}' defined for '{var1}':\n{nchar_h}")
print(nchar_h.max())
print(f"Array of type '{type(E_e_h)}' defined for '{var2}':\n{E_e_h}")
print(E_e_h.max())
print(f"Array of type '{type(E_h_h)}' defined for '{var3}':\n{E_h_h}")
print(E_h_h.max())
# Out:
# Array of type '<class 'numpy.ndarray'>' defined for 'Pcharged':
# [36.15152  62.90951  66.66082  ... 65.85204  56.341167 68.896835]
# 45531.867
# Array of type '<class 'numpy.ndarray'>' defined for 'Ncharged':
# [25. 14. 17. ... 27. 24. 21.]
# 48.0
# Array of type '<class 'numpy.ndarray'>' defined for 'E_ecal':
# [45.34248  47.437466 66.6089   ... 57.751255 55.816082 55.587524]
# 107.534386
# Array of type '<class 'numpy.ndarray'>' defined for 'E_hcal':
# [11.599842 20.09169   4.80349  ...  9.828844 10.182688 21.44458 ]
# 95.673386

# %% [markdown]
# ###### Pcharged graphs

# %%
plt.style.use('ggplot') 
plt.rcParams['figure.figsize'] = [7, 5]

plt.hist(pchar_e, bins=50, edgecolor='k', color='purple', lw=1, label='Electron')
plt.hist(pchar_h, bins=50, edgecolor='k', color='white', lw=1, label='Hadron')
plt.hist(pchar_t, bins=50, edgecolor='k', color= 'cyan', lw=1, label= 'tau')
plt.hist(pchar_m, bins=50, edgecolor='k', color='yellow', lw=1, label= 'muon')
plt.xlim(0.,100000.)
plt.xlabel('Pcharged')
plt.ylabel('Ne')
#plt.title('Pcharged')
plt.legend()
plt.show()

# %% [markdown]
# ###### Ncharged graphs

# %%
plt.style.use('ggplot') 
plt.rcParams['figure.figsize'] = [7, 5]

plt.hist(nchar_e, bins=20, edgecolor='k', color='purple', lw=1, label='Electron')
plt.hist(nchar_h, bins=20, edgecolor='k', color='white', lw=1, label='Hadron')
plt.hist(nchar_t, bins=20, edgecolor='k', color= 'cyan', lw=1, label= 'tau')
plt.hist(nchar_m, bins=20, edgecolor='k', color='yellow', lw=1, label= 'muon')
plt.xlim(0.,40.)
plt.xlabel('Ncharged')
plt.ylabel('Ne')
#plt.title('Ncharged')
plt.legend()
plt.show()

# %% [markdown]
# ###### E_ecal graphs

# %%
plt.style.use('ggplot') 
plt.rcParams['figure.figsize'] = [7, 5]

plt.hist(E_e_e, bins=50, edgecolor='k', color='purple', lw=1, label='Electron')
plt.hist(E_e_h, bins=50, edgecolor='k', color='white', lw=1, label='Hadron')
plt.hist(E_e_t, bins=50, edgecolor='k', color= 'cyan', lw=1, label= 'tau')
plt.hist(E_e_m, bins=50, edgecolor='k', color='yellow', lw=1, label= 'muon')
plt.xlim(0.,120.)
plt.xlabel('E_ecal')
plt.ylabel('Ne')
#plt.title('E_ecal')
plt.legend()
plt.show()

# %% [markdown]
# ###### E_hcal graphs

# %%
plt.style.use('ggplot') 
plt.rcParams['figure.figsize'] = [7, 5]

plt.hist(E_h_e, bins=50, edgecolor='k', color='purple', lw=1, label='Electron')
plt.hist(E_h_h, bins=50, edgecolor='k', color='white', lw=1, label='Hadron')
plt.hist(E_h_t, bins=50, edgecolor='k', color= 'cyan', lw=1, label= 'tau')
plt.hist(E_h_m, bins=50, edgecolor='k', color='yellow', lw=1, label= 'muon')
plt.xlim(0.,80.)
plt.xlabel('E_hcal')
plt.ylabel('Ne')
#plt.title('E_hcal')
plt.legend()
plt.show()

# %% [markdown]
# ### Applying cuts

# %%
## Create a mask for certain selection
mymask_e = branches_e['Pcharged'] <= 1000
#print(mymask_e)
mymask_t = branches_t['Pcharged'] <= 1000
#print(mymask_t)
mymask_m = branches_m['Pcharged'] <= 1000
#print(mymask_m)
mymask_h = branches_h['Pcharged'] <= 1000
#print(mymask_h)

## The sum of this array provides the number of events that passed this cut
print(f"A total of '{sum(mymask_e)}' out of '{len(mymask_e)}' events passed the cut 'mymask_e'")
print(f"A total of '{sum(mymask_t)}' out of '{len(mymask_t)}' events passed the cut 'mymask_t'")
print(f"A total of '{sum(mymask_m)}' out of '{len(mymask_m)}' events passed the cut 'mymask_m'")
print(f"A total of '{sum(mymask_h)}' out of '{len(mymask_h)}' events passed the cut 'mymask_h'")
# Out:
# A total of '93763' out of '93802' events passed the cut 'mymask_e'
# A total of '79191' out of '79214' events passed the cut 'mymask_t'
# A total of '94339' out of '94381' events passed the cut 'mymask_m'
# A total of '98501' out of '98563' events passed the cut 'mymask_h'

# %%
#plt.style.use(mplhep.style.ATLAS) # You can load ATLAS/CMS/ALICE plot style
plt.style.use('ggplot') 
plt.figure(figsize=(7,5))

bin_content, bin_edges, _ = plt.hist(pchar_e[mymask_e],bins=1000,range=(0,200), histtype='step',  linewidth=2, edgecolor='purple', hatch='/', label='Pcharged(e)')
bin_content, bin_edges, _ = plt.hist(pchar_t[mymask_t],bins=1000,range=(0,200), histtype='step',  linewidth=2, edgecolor='cyan', hatch='/', label='Pcharged(t)')
bin_content, bin_edges, _ = plt.hist(pchar_m[mymask_m],bins=1000,range=(0,200), histtype='step',  linewidth=2, edgecolor='yellow', hatch='/', label='Pcharged(m)')
bin_content, bin_edges, _ = plt.hist(pchar_h[mymask_h],bins=1000,range=(0,200), histtype='step',  linewidth=2, edgecolor='white', hatch='/', label='Pcharged(h)')

mid = 0.5*(bin_edges[1:] + bin_edges[:-1]) #Calculate midpoint of the bars

error_sizes = np.sqrt(bin_content)

plt.errorbar(mid, bin_content, yerr=error_sizes, fmt='none')
### When producing an histogram, you can store the bin content and the edges of the bins in 
###'bin_content', and 'bin_edges' 
#print(bin_content)
#print(bin_edges)

### Show the plot on screen
#plt.title('My title')
plt.xlim(0.,150.)
plt.ylim(0.,5000.)
plt.xlabel('Total scalar sum of track momenta, $p_{track}$')
plt.ylabel('Number of events')
plt.legend()
plt.show()

# %%
## Create a mask for certain selection
mymask_e = branches_e['Ncharged'] <= 8
#print(mymask_e)
mymask_t = branches_t['Ncharged'] <= 10
#print(mymask_t)
mymask_m = branches_m['Ncharged'] <= 5
#print(mymask_m)
mymask_h = branches_h['Ncharged'] <= 35
#print(mymask_h)

## The sum of this array provides the number of events that passed this cut
print(f"A total of '{sum(mymask_e)}' out of '{len(mymask_e)}' events passed the cut 'mymask_e'")
print(f"A total of '{sum(mymask_t)}' out of '{len(mymask_t)}' events passed the cut 'mymask_t'")
print(f"A total of '{sum(mymask_m)}' out of '{len(mymask_m)}' events passed the cut 'mymask_m'")
print(f"A total of '{sum(mymask_h)}' out of '{len(mymask_h)}' events passed the cut 'mymask_h'")
# Out:
# A total of '93801' out of '93802' events passed the cut 'mymask_e'
# A total of '79135' out of '79214' events passed the cut 'mymask_t'
# A total of '94380' out of '94381' events passed the cut 'mymask_m'
# A total of '97976' out of '98563' events passed the cut 'mymask_h'

# %%
#plt.style.use(mplhep.style.ATLAS) # You can load ATLAS/CMS/ALICE plot style
plt.style.use('ggplot') 
plt.figure(figsize=(7,5))

bin_content, bin_edges, _ = plt.hist(nchar_e[mymask_e],bins=50,range=(0,200), histtype='step',  linewidth=2, edgecolor='purple', hatch='/', label='Ncharged(e)')
bin_content, bin_edges, _ = plt.hist(nchar_t[mymask_t],bins=50,range=(0,200), histtype='step',  linewidth=2, edgecolor='cyan', hatch='/', label='Ncharged(t)')
bin_content, bin_edges, _ = plt.hist(nchar_m[mymask_m],bins=50,range=(0,200), histtype='step',  linewidth=2, edgecolor='yellow', hatch='/', label='Ncharged(m)')
bin_content, bin_edges, _ = plt.hist(nchar_h[mymask_h],bins=50,range=(0,200), histtype='step',  linewidth=2, edgecolor='white', hatch='/', label='Ncharged(h)')

mid = 0.5*(bin_edges[1:] + bin_edges[:-1]) #Calculate midpoint of the bars

error_sizes = np.sqrt(bin_content)

plt.errorbar(mid, bin_content, yerr=error_sizes, fmt='none')
### When producing an histogram, you can store the bin content and the edges of the bins in 
###'bin_content', and 'bin_edges' 
#print(bin_content)
#print(bin_edges)

### Show the plot on screen
#plt.title('My title')
plt.xlim(0.,40.)
#plt.ylim(0.,10000.)
plt.xlabel('$N_{track}$')
plt.ylabel('Number of events')
plt.legend()
plt.show()

# %%
## Create a mask for certain selection
mymask_e = branches_e['E_ecal'] >= 75
#print(mymask_e)
mymask_t = branches_t['E_ecal'] <= 60
#print(mymask_t)
mymask_m = branches_m['E_ecal'] <= 20
#print(mymask_m)
mymask_h = branches_h['E_ecal'] >= 35
#print(mymask_h)

## The sum of this array provides the number of events that passed this cut
print(f"A total of '{sum(mymask_e)}' out of '{len(mymask_e)}' events passed the cut 'mymask_e'")
print(f"A total of '{sum(mymask_t)}' out of '{len(mymask_t)}' events passed the cut 'mymask_t'")
print(f"A total of '{sum(mymask_m)}' out of '{len(mymask_m)}' events passed the cut 'mymask_m'")
print(f"A total of '{sum(mymask_h)}' out of '{len(mymask_h)}' events passed the cut 'mymask_h'")
# Out:
# A total of '90525' out of '93802' events passed the cut 'mymask_e'
# A total of '75936' out of '79214' events passed the cut 'mymask_t'
# A total of '91736' out of '94381' events passed the cut 'mymask_m'
# A total of '95783' out of '98563' events passed the cut 'mymask_h'

# %%
#plt.style.use(mplhep.style.ATLAS) # You can load ATLAS/CMS/ALICE plot style
plt.style.use('ggplot') 
plt.figure(figsize=(7,5))

bin_content, bin_edges, _ = plt.hist(E_e_e[mymask_e],bins=1000,range=(0,200), histtype='step',  linewidth=2, edgecolor='purple', hatch='/', label='E_ecal(e)')
bin_content, bin_edges, _ = plt.hist(E_e_t[mymask_t],bins=1000,range=(0,200), histtype='step',  linewidth=2, edgecolor='cyan', hatch='/', label='E_ecal(t)')
bin_content, bin_edges, _ = plt.hist(E_e_m[mymask_m],bins=1000,range=(0,200), histtype='step',  linewidth=2, edgecolor='yellow', hatch='/', label='E_ecal(m)')
bin_content, bin_edges, _ = plt.hist(E_e_h[mymask_h],bins=1000,range=(0,200), histtype='step',  linewidth=2, edgecolor='white', hatch='/', label='E_ecal(h)')

mid = 0.5*(bin_edges[1:] + bin_edges[:-1]) #Calculate midpoint of the bars

error_sizes = np.sqrt(bin_content)

plt.errorbar(mid, bin_content, yerr=error_sizes, fmt='none')
### When producing an histogram, you can store the bin content and the edges of the bins in 
###'bin_content', and 'bin_edges' 
#print(bin_content)
#print(bin_edges)

### Show the plot on screen
#plt.title('My title')
plt.xlim(0.,125.)
#plt.ylim(0.,10000.)
plt.xlabel('E_ecal')
plt.ylabel('Number of events')
plt.legend()
plt.show()

# %%
## Create a mask for certain selection
mymask_e = branches_e['E_hcal'] <= 20
#print(mymask_e)
mymask_t = branches_t['E_hcal'] <= 40
#print(mymask_t)
mymask_m = branches_m['E_hcal'] <= 20
#print(mymask_m)
mymask_h = branches_h['E_hcal'] <= 40
#print(mymask_h)

## The sum of this array provides the number of events that passed this cut
print(f"A total of '{sum(mymask_e)}' out of '{len(mymask_e)}' events passed the cut 'mymask_e'")
print(f"A total of '{sum(mymask_t)}' out of '{len(mymask_t)}' events passed the cut 'mymask_t'")
print(f"A total of '{sum(mymask_m)}' out of '{len(mymask_m)}' events passed the cut 'mymask_m'")
print(f"A total of '{sum(mymask_h)}' out of '{len(mymask_h)}' events passed the cut 'mymask_h'")
# Out:
# A total of '93737' out of '93802' events passed the cut 'mymask_e'
# A total of '78689' out of '79214' events passed the cut 'mymask_t'
# A total of '94030' out of '94381' events passed the cut 'mymask_m'
# A total of '96851' out of '98563' events passed the cut 'mymask_h'

# %%
#plt.style.use(mplhep.style.ATLAS) # You can load ATLAS/CMS/ALICE plot style
plt.style.use('ggplot') 
plt.figure(figsize=(7,5))

bin_content, bin_edges, _ = plt.hist(E_h_e[mymask_e],bins=1000,range=(0,200), histtype='step',  linewidth=2, edgecolor='purple', hatch='/', label='E_hcal(e)')
bin_content, bin_edges, _ = plt.hist(E_h_t[mymask_t],bins=1000,range=(0,200), histtype='step',  linewidth=2, edgecolor='cyan', hatch='/', label='E_hcal(t)')
bin_content, bin_edges, _ = plt.hist(E_h_m[mymask_m],bins=1000,range=(0,200), histtype='step',  linewidth=2, edgecolor='yellow', hatch='/', label='E_hcal(m)')
bin_content, bin_edges, _ = plt.hist(E_h_h[mymask_h],bins=1000,range=(0,200), histtype='step',  linewidth=2, edgecolor='white', hatch='/', label='E_hcal(h)')

mid = 0.5*(bin_edges[1:] + bin_edges[:-1]) #Calculate midpoint of the bars

error_sizes = np.sqrt(bin_content)

plt.errorbar(mid, bin_content, yerr=error_sizes, fmt='none')
### When producing an histogram, you can store the bin content and the edges of the bins in 
###'bin_content', and 'bin_edges' 
#print(bin_content)
#print(bin_edges)

### Show the plot on screen
#plt.title('My title')
plt.xlim(0.,100.)
plt.ylim(0.,5000.)
plt.xlabel('E_hcal')
plt.ylabel('Number of events')
plt.legend()
plt.show()

# %% [markdown]
# ### Calculating matrix efficiency and errors

# %%
def Count(pchar_e,nchar_e,E_e_e,E_h_e,pchar_t,nchar_t,E_e_t,E_h_t,pchar_m,nchar_m,E_e_m,E_h_m,pchar_h,nchar_h,E_e_h,E_h_h): 
    Electrons=0
    Taus=0
    Muons=0
    Hadrons=0
    for i in range(0,len(nchar_e)):
        if E_e_e[i]>=70 and E_h_e[i]<=10 and nchar_e[i]<=6:
            Electrons+=1
    for j in range(0,len(nchar_t)):
        if E_e_t[j]>=70 and E_h_t[j]<=10 and nchar_t[j]<=6:
            Taus+=1
    for k in range(0,len(nchar_m)):
        if E_e_m[k]>=70 and E_h_m[k]<=10 and nchar_m[k]<=6:
            Muons+=1
    for l in range(0,len(nchar_h)):
        if E_e_h[l]>=70 and E_h_h[l]<=10 and nchar_h[l]<=6:
            Hadrons+=1
    return np.array([Electrons, Taus, Muons, Hadrons])

# %%
Electrons,Taus,Muons,Hadrons = Count(pchar_e,nchar_e,E_e_e,E_h_e,pchar_t,nchar_t,E_e_t,E_h_t,pchar_m,nchar_m,E_e_m,E_h_m,pchar_h,nchar_h,E_e_h,E_h_h) 
#Efficiency = N(cut)/N
print('Efficiency =', Electrons/len(nchar_e))
print('Efficiency =', Taus/len(nchar_t))
print('Efficiency =', Muons/len(nchar_m))
print('Efficiency =', Hadrons/len(nchar_h))
# Out:
# Efficiency = 0.9756401782477986
# Efficiency = 0.010174969071123792
# Efficiency = 0.0
# Efficiency = 0.00028408226210647

# %%
# Errors 
# Using Poisson distribution 
error_e = np.sqrt((np.sqrt(Electrons)/len(nchar_e))**2+(np.sqrt(len(nchar_e))*Electrons/len(nchar_e)**2)**2)
print('Error =', error_e)
error_t = np.sqrt((np.sqrt(Taus)/len(nchar_t))**2+(np.sqrt(len(nchar_t))*Taus/len(nchar_t)**2)**2)
print('Error =', error_t)
error_m = np.sqrt((np.sqrt(Muons)/len(nchar_m))**2+(np.sqrt(len(nchar_m))*Muons/len(nchar_m)**2)**2)
print('Error =', error_m)
error_h = np.sqrt((np.sqrt(Hadrons)/len(nchar_h))**2+(np.sqrt(len(nchar_h))*Hadrons/len(nchar_h)**2)**2)
print('Error =', error_h)
# Out:
# Error = 0.004533073012851596
# Error = 0.0003602167291191659
# Error = 0.0
# Error = 5.369412639402556e-05

# %%
def Count(pchar_e,nchar_e,E_e_e,E_h_e,pchar_t,nchar_t,E_e_t,E_h_t,pchar_m,nchar_m,E_e_m,E_h_m,pchar_h,nchar_h,E_e_h,E_h_h): 
    Electrons=0
    Taus=0
    Muons=0
    Hadrons=0
    for i in range(0,len(nchar_e)):
        if pchar_e[i]<=65 and nchar_e[i]<=6 and E_e_e[i]<=60:
            Electrons+=1
    for j in range(0,len(nchar_t)):
        if pchar_t[j]<=65 and nchar_t[j]<=6 and E_e_t[j]<=60:
            Taus+=1
    for k in range(0,len(nchar_m)):
        if pchar_m[k]<=65 and nchar_m[k]<=6 and E_e_m[k]<=60:
            Muons+=1
    for l in range(0,len(nchar_h)):
        if pchar_h[l]<=65 and nchar_h[l]<=6 and E_e_h[l]<=60:
            Hadrons+=1
    return np.array([Electrons, Taus, Muons, Hadrons])

# %%
Electrons,Taus,Muons,Hadrons = Count(pchar_e,nchar_e,E_e_e,E_h_e,pchar_t,nchar_t,E_e_t,E_h_t,pchar_m,nchar_m,E_e_m,E_h_m,pchar_h,nchar_h,E_e_h,E_h_h) 
#Efficiency = N(cut)/N
print('Efficiency =', Electrons/len(nchar_e))
print('Efficiency =', Taus/len(nchar_t))
print('Efficiency =', Muons/len(nchar_m))
print('Efficiency =', Hadrons/len(nchar_h))
# Out:
# Efficiency = 0.003731263725720134
# Efficiency = 0.9028707046734163
# Efficiency = 0.0694949195282949
# Efficiency = 0.004159775980844739

# %%
# Errors 
# Using Poisson distribution 
error_e = np.sqrt((np.sqrt(Electrons)/len(nchar_e))**2+(np.sqrt(len(nchar_e))*Electrons/len(nchar_e)**2)**2)
print('Error =', error_e)
error_t = np.sqrt((np.sqrt(Taus)/len(nchar_t))**2+(np.sqrt(len(nchar_t))*Taus/len(nchar_t)**2)**2)
print('Error =', error_t)
error_m = np.sqrt((np.sqrt(Muons)/len(nchar_m))**2+(np.sqrt(len(nchar_m))*Muons/len(nchar_m)**2)**2)
print('Error =', error_m)
error_h = np.sqrt((np.sqrt(Hadrons)/len(nchar_h))**2+(np.sqrt(len(nchar_h))*Hadrons/len(nchar_h)**2)**2)
print('Error =', error_h)
# Out:
# Error = 0.00019981617889604786
# Error = 0.004657109494826804
# Error = 0.0008874085400054324
# Error = 0.0002058635344643383

# %%
def Count(pchar_e,nchar_e,E_e_e,E_h_e,pchar_t,nchar_t,E_e_t,E_h_t,pchar_m,nchar_m,E_e_m,E_h_m,pchar_h,nchar_h,E_e_h,E_h_h): 
    Electrons=0
    Taus=0
    Muons=0
    Hadrons=0
    for i in range(0,len(nchar_e)):
        if E_e_e[i]<=15 and nchar_e[i]<=6 and E_h_e[i]<=15 and pchar_e[i]>=60:
            Electrons+=1
    for j in range(0,len(nchar_t)):
        if E_e_t[j]<=15 and nchar_t[j]<=6 and E_h_t[j]<=15 and pchar_t[j]>=60:
            Taus+=1
    for k in range(0,len(nchar_m)):
        if E_e_m[k]<=15 and nchar_m[k]<=6 and E_h_m[k]<=15 and pchar_m[k]>=60:
            Muons+=1
    for l in range(0,len(nchar_h)):
        if E_e_h[l]<=15 and nchar_h[l]<=6 and E_h_h[l]<=15 and pchar_h[l]>=60:
            Hadrons+=1
    return np.array([Electrons, Taus, Muons, Hadrons])

# %%
Electrons,Taus,Muons,Hadrons = Count(pchar_e,nchar_e,E_e_e,E_h_e,pchar_t,nchar_t,E_e_t,E_h_t,pchar_m,nchar_m,E_e_m,E_h_m,pchar_h,nchar_h,E_e_h,E_h_h) 
#Efficiency = N(cut)/N
print('Efficiency =', Electrons/len(nchar_e))
print('Efficiency =', Taus/len(nchar_t))
print('Efficiency =', Muons/len(nchar_m))
print('Efficiency =', Hadrons/len(nchar_h))
# Out:
# Efficiency = 0.0
# Efficiency = 0.005175852753301184
# Efficiency = 0.89628209067503
# Efficiency = 0.0

# %%
# Errors 
# Using Poisson distribution 
error_e = np.sqrt((np.sqrt(Electrons)/len(nchar_e))**2+(np.sqrt(len(nchar_e))*Electrons/len(nchar_e)**2)**2)
print('Error =', error_e)
error_t = np.sqrt((np.sqrt(Taus)/len(nchar_t))**2+(np.sqrt(len(nchar_t))*Taus/len(nchar_t)**2)**2)
print('Error =', error_t)
error_m = np.sqrt((np.sqrt(Muons)/len(nchar_m))**2+(np.sqrt(len(nchar_m))*Muons/len(nchar_m)**2)**2)
print('Error =', error_m)
error_h = np.sqrt((np.sqrt(Hadrons)/len(nchar_h))**2+(np.sqrt(len(nchar_h))*Hadrons/len(nchar_h)**2)**2)
print('Error =', error_h)
# Out:
# Error = 0.0
# Error = 0.0002562778122031036
# Error = 0.004243571692359116
# Error = 0.0

# %%
def Count(pchar_e,nchar_e,E_e_e,E_h_e,pchar_t,nchar_t,E_e_t,E_h_t,pchar_m,nchar_m,E_e_m,E_h_m,pchar_h,nchar_h,E_e_h,E_h_h): 
    Electrons=0
    Taus=0
    Muons=0
    Hadrons=0
    for i in range(0,len(nchar_e)):
        if nchar_e[i]>=6 and E_e_e[i]<=80 and E_e_e[i]>=40:
            Electrons+=1
    for j in range(0,len(nchar_t)):
        if nchar_t[j]>=6 and E_e_t[j]<=80 and E_e_t[j]>=40:
            Taus+=1
    for k in range(0,len(nchar_m)):
        if nchar_m[k]>=6 and E_e_m[k]<=80 and E_e_m[k]>=40:
            Muons+=1
    for l in range(0,len(nchar_h)):
        if nchar_h[l]>=6 and E_e_h[l]<=80 and E_e_h[l]>=40:
            Hadrons+=1
    return np.array([Electrons, Taus, Muons, Hadrons])

# %%
Electrons,Taus,Muons,Hadrons = Count(pchar_e,nchar_e,E_e_e,E_h_e,pchar_t,nchar_t,E_e_t,E_h_t,pchar_m,nchar_m,E_e_m,E_h_m,pchar_h,nchar_h,E_e_h,E_h_h) 
#Efficiency = N(cut)/N
print('Efficiency =', Electrons/len(nchar_e))
print('Efficiency =', Taus/len(nchar_t))
print('Efficiency =', Muons/len(nchar_m))
print('Efficiency =', Hadrons/len(nchar_h))
# Out:
# Efficiency = 5.3303767510287626e-05
# Efficiency = 0.020514050546620546
# Efficiency = 0.0
# Efficiency = 0.91613485790814

# %%
# Errors 
# Using Poisson distribution 
error_e = np.sqrt((np.sqrt(Electrons)/len(nchar_e))**2+(np.sqrt(len(nchar_e))*Electrons/len(nchar_e)**2)**2)
print('Error =', error_e)
error_t = np.sqrt((np.sqrt(Taus)/len(nchar_t))**2+(np.sqrt(len(nchar_t))*Taus/len(nchar_t)**2)**2)
print('Error =', error_t)
error_m = np.sqrt((np.sqrt(Muons)/len(nchar_m))**2+(np.sqrt(len(nchar_m))*Muons/len(nchar_m)**2)**2)
print('Error =', error_m)
error_h = np.sqrt((np.sqrt(Hadrons)/len(nchar_h))**2+(np.sqrt(len(nchar_h))*Hadrons/len(nchar_h)**2)**2)
print('Error =', error_h)
# Out:
# Error = 2.3838804845626436e-05
# Error = 0.0005140841722160213
# Error = 0.0
# Error = 0.004220226719470882

# %%
# Matrix 
                          # e                    # t                    # m                      # h
matrix = np.array([[0.9756401782477986,     0.010174969071123792,  0.00000000000000000,  0.00028408226210647], # e
                   [0.003731263725720134,    0.9028707046734163,    0.0694949195282949,    0.004159775980844739], # t
                   [0.00000000000000000,    0.005175852753301184,     0.89628209067503,      0.00000000000000000], # m
                   [5.3303767510287626e-05,  0.020514050546620546,   0.00000000000000000,  0.91613485790814]])# h

# %%
# Errors matrix 
                          # e                    # t                    # m                      # h
error_matrix = np.array([[0.004533073012851596, 0.0003602167291191659,  0.00000000000000000, 5.369412639402556e-05], # e
                   [0.00019981617889604786,   0.004657109494826804,    0.0008874085400054324,   0.0002058635344643383], # t
                   [0.00000000000000000,     0.0002562778122031036,    0.004243571692359116,    0.00000000000000000], # m
                   [2.3838804845626436e-05,  0.0005140841722160213,   0.00000000000000000,  0.004220226719470882]])# h

# %%
matrix_inverse= np.linalg.inv(matrix)
print(matrix_inverse)
# Out:
# [[ 1.02501223e+00 -1.15505562e-02  8.95594122e-04 -2.65397680e-04]
#  [-4.23808018e-03  1.10823296e+00 -8.59289296e-02 -5.03069703e-03]
#  [ 2.44740793e-05 -6.39982736e-03  1.11621639e+00  2.90512857e-05]
#  [ 3.52602866e-05 -2.48148307e-02  1.92406462e-03  1.09165502e+00]]

# %% [markdown]
# ### Fit a distribution and matrix inversion

# %%
from scipy.optimize import curve_fit

### Number of toy experiments to be done
ntoy = 10000

### Create numpy matrix of list to append elements of inverted toy matrices
inverse_toys = np.empty((4,4))

# Create toy efficiency matrix out of gaussian-distributed random values
for i in range(0,ntoy,1):
    toy_matrix = np.zeros((4,4))
    toy_matrix = np.random.normal(matrix,error_matrix,size=(4,4))
    
    ### Invert toy matrix
    inverse_toy = np.linalg.inv(toy_matrix)
    
    #print(inverse_toys.item(0,0),inverse_toy.item(0,0))
    # Append values
    inverse_toys = np.dstack((inverse_toys,inverse_toy))
    
# Define gaussian function to fit to the toy distributions:
def gauss(x, A, mu, sigma):
    return A*np.exp(-(x-mu)**2/(2.*sigma**2))


inverse_errors = np.zeros((4,4))
inverse_means = np.zeros((4,4))


fig = plt.figure(figsize=(20, 10),dpi=80)
fig.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.2, hspace=0.2)
ax00 = plt.subplot(4,4,1)
ax01 = plt.subplot(4,4,2)
ax02 = plt.subplot(4,4,3)
ax03 = plt.subplot(4,4,4)

ax10 = plt.subplot(4,4,5)
ax11 = plt.subplot(4,4,6)
ax12 = plt.subplot(4,4,7)
ax13 = plt.subplot(4,4,8)

ax20 = plt.subplot(4,4,9)
ax21 = plt.subplot(4,4,10)
ax22 = plt.subplot(4,4,11)
ax23 = plt.subplot(4,4,12)

ax30 = plt.subplot(4,4,13)
ax31 = plt.subplot(4,4,14)
ax32 = plt.subplot(4,4,15)
ax33 = plt.subplot(4,4,16)

axes = [[ax00,ax01,ax02,ax03],
        [ax10,ax11,ax12,ax13],
        [ax20,ax21,ax22,ax23],
        [ax30,ax31,ax32,ax33]]


# Fill histograms for each inverted matrix coefficient:
for j in range(0,4,1):
    for k in range(0,4,1):
        
        ## Guess initial parameters for the fit, use them for proper ranges of the histograms below
        p0 = [ntoy/10.,np.mean(inverse_toys[j,k,:]),np.std(inverse_toys[j,k,:])]
        
        # Generate the histograms of the matrix elements of the toys
        hbins, hedges, _ = axes[j][k].hist(inverse_toys[j,k,:],bins=np.linspace(p0[1]-4*p0[2],p0[1]+4*p0[2],200), histtype='step', color='k', linewidth=2, label=f'toyhist{j}{k}')
        axes[j][k].legend()


        # Get the fitted curve
        h_mid = 0.5*(hedges[1:] + hedges[:-1]) #Calculate midpoints for the fit
        coeffs, _ = curve_fit(gauss, h_mid, hbins,p0, maxfev=1000)
        h_fit = gauss(h_mid, *coeffs)
        
        axes[j][k].plot(h_mid, h_fit,label=f'Fit{j}{k}')
                

        inverse_means[j,k] = coeffs[1]
        inverse_errors[j,k] = abs(coeffs[2])
            

print(f"Errors for the inverse matrix:\n{inverse_errors}")
print(f"Means for the inverse matrix:\n{inverse_means}")
# Out:
# Errors for the inverse matrix:
# [[4.81779885e-03 4.09677486e-04 3.39825966e-05 6.04513343e-05]
#  [2.31176884e-04 5.67373312e-03 1.24458981e-03 2.59407901e-04]
#  [1.80287555e-06 3.19689136e-04 5.35137821e-03 2.07722759e-06]
#  [2.78218874e-05 6.54878244e-04 5.72045111e-05 4.98431126e-03]]
# Means for the inverse matrix:
# [[ 1.02500577e+00 -1.15498189e-02  8.94974456e-04 -2.65767490e-04]
#  [-4.23887343e-03  1.10815048e+00 -8.59382657e-02 -5.03322972e-03]
#  [ 2.44215367e-05 -6.39681994e-03  1.11612087e+00  2.89764168e-05]
#  [ 3.47366260e-05 -2.48101538e-02  1.92330026e-03  1.09157550e+00]]

# %% [markdown]
# ### Separating s-channel and t-channel

# %%
from scipy.optimize import curve_fit

# to seperate the two channels we use the electrons files and load cos for the angle
path_data = 'Data/'
#path_mc = 'samples/data'

### Open the file introducing file path
file = uproot.open(path_data+'ee.root')
ttree_name = 'myTTree'

### Print list of 'branches' of the TTree (i.e. list of variable names)
file[ttree_name].keys()

## Load branches
branches_e = file[ttree_name].arrays()

## Define an numpy array for 'Pcharged'
var4 = 'cos_thru'
var5 = 'cos_thet'

cos_ru_e = ak.to_numpy(branches_e[var4]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions
cos_et_e = ak.to_numpy(branches_e[var5]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions

print(f"Array of type '{type(cos_ru_e)}' defined for '{var4}':\n{cos_ru_e}")
print(cos_ru_e.max())
print(f"Array of type '{type(cos_et_e)}' defined for '{var5}':\n{cos_et_e}")
print(cos_et_e.max())

#angle = np.linspace(-0.95,0.95,180) # for good measurements.
angle = np.linspace(-0.92,0.92,180) # for good measurements.
#angle = np.linspace(-0.9,0.9,180) # for good measurements.

# s-channel dominates for large angles proportional to (1+cos(teta)**2) and the t-channels with dominates for small 
# angles proportional to (1-cos(teta))**(-2) so we have as a fit function :
def fun(cos,s,t): 
     return s*(1+cos**2) + t/((1-cos)**(2))
    
new_bin_content, new_bin_edges,_ =plt.hist(cos_et_e,angle,edgecolor='white',color='white')
new_mid = 0.5*(new_bin_edges[1:] + new_bin_edges[:-1])
coeffs, variables = curve_fit(fun, new_mid, new_bin_content)
print(" Coefficients [s   t]:",coeffs)

plt.plot(angle,fun(angle,*coeffs),color='y',label="fit function")
plt.plot(angle,coeffs[1]*(1-angle)**(-2),color='k',label="t-channel")
plt.plot(angle,coeffs[0]*(1+angle**2),color='m',label="s-channel")
plt.legend()
plt.show()
# Out:
# Array of type '<class 'numpy.ndarray'>' defined for 'cos_thru':
# [999. 999. 999. ... 999. 999. 999.]
# 999.0
# Array of type '<class 'numpy.ndarray'>' defined for 'cos_thet':
# [-8.5578871e-01 -3.6037236e-01  9.9900000e+02 ...  7.3445606e-01
#  -8.6465836e-01  8.7902808e-01]
# 999.0
#  Coefficients [s   t]: [117.81876189  11.85858801]

# %% [markdown]
# We can see that the two contributions are equals at 0.75 so we choose either this point to cut for more t-channel
# events or a lower value than 0.75 to have more s-channel events. in our case we will choose 0.7 as cut.

# %% [markdown]
# ### Measuring of the total production cross sections

# %%
path_data = 'Data/'
#path_mc = 'samples/data'

### Open the file introducing file path
file = uproot.open(path_data+'daten_4.root')
ttree_name = 'myTTree'

### Print list of 'branches' of the TTree (i.e. list of variable names)
file[ttree_name].keys()

## Load branches
branches= file[ttree_name].arrays()

## Define an numpy array for 'Pcharged'
var = 'Pcharged'
var1 = 'Ncharged'
var2 = 'E_ecal'
var3 = 'E_hcal'
var4 = 'E_lep'
var5 = 'cos_thet'

pchar= ak.to_numpy(branches[var]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions
nchar= ak.to_numpy(branches[var1]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions
E_e= ak.to_numpy(branches[var2]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions
E_h= ak.to_numpy(branches[var3]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions
E_l= ak.to_numpy(branches[var4]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions
cos_et= ak.to_numpy(branches[var5]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions

print(f"Array of type '{type(pchar)}' defined for '{var}':\n{pchar}")
print(pchar.max())
print(f"Array of type '{type(nchar)}' defined for '{var1}':\n{nchar}")
print(nchar.max())
print(f"Array of type '{type(E_e)}' defined for '{var2}':\n{E_e}")
print(E_e.max())
print(f"Array of type '{type(E_h)}' defined for '{var3}':\n{E_h}")
print(E_h.max())
print(f"Array of type '{type(E_l)}' defined for '{var4}':\n{E_l}")
print(E_l.max())
print(f"Array of type '{type(cos_et)}' defined for '{var5}':\n{cos_et}")
print(cos_et.max())
# Out:
# Array of type '<class 'numpy.ndarray'>' defined for 'Pcharged':
# [96.253746 60.225136 49.156116 ... 74.57058  51.337208 72.23964 ]
# 56728.812
# Array of type '<class 'numpy.ndarray'>' defined for 'Ncharged':
# [ 2. 23. 12. ... 16. 21. 23.]
# 50.0
# Array of type '<class 'numpy.ndarray'>' defined for 'E_ecal':
# [ 2.0577164 35.80598   53.235523  ... 55.183556  57.176117  60.440258 ]
# 134.46292
# Array of type '<class 'numpy.ndarray'>' defined for 'E_hcal':
# [ 3.5210338  5.6290207  0.        ...  2.7485452 10.511894   5.618365 ]
# 536.4056
# Array of type '<class 'numpy.ndarray'>' defined for 'E_lep':
# [45.627 45.627 45.627 ... 44.732 44.732 44.732]
# 46.862
# Array of type '<class 'numpy.ndarray'>' defined for 'cos_thet':
# [-6.1867344e-01  9.9900000e+02  9.9900000e+02 ...  9.9900000e+02
#   9.9900000e+02  9.9900000e+02]
# 999.0

# %%
import csv

path_data = 'Data/'
file = open(path_data+'daten_4.csv')
csvreader = csv.reader(file)
header = []
header = next(csvreader)
header
# Out:
# ['meanenergy', 'lumi', 'stat', 'sys', 'all']

# %%
rows = []
for row in csvreader:
        rows.append(row)
rows
# Out:
# [['88.47939', '463.9790', '2.902361', '3.104100', '4.249604    '],
#  ['89.46793', '667.5236', '3.521166', '4.471900', '5.691792    '],
#  ['90.22266', '486.7641', '3.033955', '3.261500', '4.454466    '],
#  ['91.22430', '2246.568', '6.603405', '15.04780', '16.43293    '],
#  ['91.96648', '535.9080', '3.265110', '3.585300', '4.849260    '],
#  ['92.96465', '450.6000', '3.027953', '3.020000', '4.276552    '],
#  ['93.71712', '709.6980', '3.819882', '4.762000', '6.104764    ']]

# %%
com_energies = [88.47939,89.46793,90.22266,91.22430,91.96648,92.96465,93.71712] #array with CoM energies
E_lep_cut = [44.2, 44.7, 45.1, 45.6, 46.0, 46.5, 46.9]  # mean of C0M energies of data

#lumi = [463.9790,667.5236,486.7641,2246.568,535.9080,450.6000,709.6980]
#lumi_all = [4.249604,5.691792,4.454466,16.43293,4.849260,4.276552,6.104764]


N_events = [0,0,0,0,0,0,0]
for i in range(0,len(E_l)):
    for j in range(7):
        if (E_l[i] >= E_lep_cut[j]-0.1 and E_l[i] <= E_lep_cut[j]+0.1):
            N_events[j]+=1
for i in range(7):
    print("There are ", N_events[i], " events for CoM energy ", com_energies[i])
# Out:
# There are  4332  events for CoM energy  88.47939
# There are  9747  events for CoM energy  89.46793
# There are  11507  events for CoM energy  90.22266
# There are  82009  events for CoM energy  91.2243
# There are  16043  events for CoM energy  91.96648
# There are  8065  events for CoM energy  92.96465
# There are  9441  events for CoM energy  93.71712

# %%
# daten_4 datas
def Count_new(N_events,pchar,nchar,E_e,E_h,cos_et): 
    Electrons= [0,0,0,0,0,0,0]
    Taus=[0,0,0,0,0,0,0]
    Muons=[0,0,0,0,0,0,0]
    Hadrons=[0,0,0,0,0,0,0]
    for k in range(7):
        for i in range(0,N_events[k]):
            if E_e[i]>=70 and E_h[i]<=10 and nchar[i]<=6 and cos_et[i]>=-0.9 and cos_et[i]<=0.7:
                Electrons[k]+=1
            if pchar[i]<=65 and nchar[i]<=6 and E_e[i]<=60:
                Taus[k]+=1
            if E_e[i]<=15 and nchar[i]<=6 and E_h[i]<=15 and pchar[i]>=60:
                Muons[k]+=1
            if nchar[i]>=6 and E_e[i]<=80 and E_e[i]>=40:
                Hadrons[k]+=1
    return Electrons, Taus, Muons, Hadrons

Electrons,Taus,Muons,Hadrons = Count_new(N_events,pchar,nchar,E_e,E_h,cos_et)

print('Events_e =', Electrons)
print('Events_t =', Taus)
print('Events_m =', Muons)
print('Events_h =', Hadrons)
# Out:
# Events_e = [130, 275, 318, 2320, 449, 230, 265]
# Events_t = [176, 388, 440, 2982, 620, 313, 373]
# Events_m = [139, 327, 377, 2737, 514, 276, 315]
# Events_h = [3177, 7098, 8387, 58393, 11727, 5904, 6889]

# %%
# Errors 
# Using Poisson distribution 
error_e= [0,0,0,0,0,0,0]
error_t= [0,0,0,0,0,0,0]
error_m= [0,0,0,0,0,0,0]
error_h= [0,0,0,0,0,0,0]

for i in range(7):
    error_e[i] = np.sqrt((np.sqrt(Electrons[i])/N_events[i])**2+(np.sqrt(N_events[i])*Electrons[i]/N_events[i]**2)**2)
    error_t[i] = np.sqrt((np.sqrt(Taus[i])/N_events[i])**2+(np.sqrt(N_events[i])*Taus[i]/N_events[i]**2)**2)
    error_m[i] = np.sqrt((np.sqrt(Muons[i])/N_events[i])**2+(np.sqrt(N_events[i])*Muons[i]/N_events[i]**2)**2)
    error_h[i] = np.sqrt((np.sqrt(Hadrons[i])/N_events[i])**2+(np.sqrt(N_events[i])*Hadrons[i]/N_events[i]**2)**2)

print('Errors_e =', error_e)
print('Errors_t =', error_t)
print('Errors_m =', error_m)
print('Errors_h =', error_h)
# Out:
# Errors_e = [0.002671183892385444, 0.0017251906550963282, 0.0015709811175475062, 0.0005955801204925846, 0.00133915688446302, 0.0019070652630404571, 0.001748300508995919]
# Errors_t = [0.0031240330206117307, 0.002060730933039655, 0.001857430619030633, 0.0006778724984698854, 0.0015817726669555443, 0.002235814607228143, 0.0020856933011798168]
# Errors_m = [0.0027648849410909972, 0.0018861160055177143, 0.0017147816483437852, 0.0006484921580551306, 0.001435634904089007, 0.002094869839071582, 0.0019110153534292432]
# Errors_h = [0.017130379633262343, 0.011363105949833145, 0.010464565692647825, 0.0038554472619864366, 0.008880819171893314, 0.012538606569200769, 0.011562298794868116]

# %%
Events_1 = np.array([[130],
                   [176],  
                   [139], 
                   [3177]])
Events_2 = np.array([[275],
                   [388],  
                   [327], 
                   [7098]])
Events_3 = np.array([[318],
                   [440],  
                   [377], 
                   [8387]])
Events_4 = np.array([[2320],
                   [2982],  
                   [2737], 
                   [58393]])
Events_5 = np.array([[449],
                   [620],  
                   [514], 
                   [11727]])
Events_6 = np.array([[230],
                   [313],  
                   [276], 
                   [5904]])
Events_7 = np.array([[265],
                   [373],  
                   [315], 
                   [6889]])

Events_1_new = np.dot(inverse_means,Events_1)
print('Events_1_new=', Events_1_new)
Events_2_new = np.dot(inverse_means,Events_2)
print('Events_2_new=', Events_2_new)
Events_3_new = np.dot(inverse_means,Events_3)
print('Events_3_new=', Events_3_new)
Events_4_new = np.dot(inverse_means,Events_4)
print('Events_4_new=', Events_4_new)
Events_5_new = np.dot(inverse_means,Events_5)
print('Events_5_new=', Events_5_new)
Events_6_new = np.dot(inverse_means,Events_6)
print('Events_6_new=', Events_6_new)
Events_7_new = np.dot(inverse_means,Events_7)
print('Events_7_new=', Events_7_new)
# Out:
# Events_1_new= [[ 130.49804005]
#  [ 166.54744148]
#  [ 154.11019415]
#  [3463.84063614]]
# Events_2_new= [[ 275.8014959 ]
#  [ 364.96901927]
#  [ 362.70195041]
#  [7739.01504272]]
# Events_3_new= [[ 318.97832783]
#  [ 411.62582637]
#  [ 418.21376023]
#  [9144.86339503]]
# Events_4_new= [[ 2330.50240945]
#  [ 2765.55213384]
#  [ 3037.49619478]
#  [63671.72905043]]
# Events_5_new= [[  450.41006433]
#  [  581.95309099]
#  [  570.07087293]
#  [12786.52778546]]
# Events_6_new= [[ 230.81415537]
#  [ 292.44101029]
#  [ 306.22385049]
#  [6437.43500384]]
# Events_7_new= [[ 265.7694912 ]
#  [ 350.47235498]
#  [ 349.39815193]
#  [7511.22448822]]

# %%
Events_new_e=[130.50211314,275.81007027,318.988256,2330.57555491,450.4240819,230.82135906,265.77775364]
Events_new_t=[166.58773402,365.05882477,411.72838111,2766.25776361,582.09673086,292.51424683,350.55880016]
Events_new_m=[154.10053004,362.67925974,418.18761348,3037.30673799,570.03519022,306.20472395,349.37629542]
Events_new_h=[3463.8380614,7739.00936589,9144.85694676,63671.68536695,12786.51869859,6437.43042203,7511.21902854]

# %%
Errors_1 = np.array([[0.002671183892385444],
                   [0.0031240330206117307],  
                   [0.0027648849410909972], 
                   [0.017130379633262343]])
Errors_2 = np.array([[0.0017251906550963282],
                   [0.002060730933039655],  
                   [0.0018861160055177143], 
                   [0.011363105949833145]])
Errors_3 = np.array([[0.0015709811175475062],
                   [0.001857430619030633],  
                   [0.0017147816483437852], 
                   [0.010464565692647825]])
Errors_4 = np.array([[0.0005955801204925846],
                   [0.0006778724984698854],  
                   [0.0006484921580551306], 
                   [0.0038554472619864366]])
Errors_5 = np.array([[0.00133915688446302],
                   [0.0015817726669555443],  
                   [0.001435634904089007], 
                   [0.008880819171893314]])
Errors_6 = np.array([[0.0019070652630404571],
                   [0.002235814607228143],  
                   [0.002094869839071582], 
                   [0.012538606569200769]])
Errors_7 = np.array([[0.001748300508995919],
                   [0.0020856933011798168],  
                   [0.0019110153534292432], 
                   [0.011562298794868116]])

Errors_1_new = np.dot(inverse_errors,Errors_1)
print('Errors_1_new=', Errors_1_new)
Errors_2_new = np.dot(inverse_errors,Errors_2)
print('Errors_2_new=', Errors_2_new)
Errors_3_new = np.dot(inverse_errors,Errors_3)
print('Errors_3_new=', Errors_3_new)
Errors_4_new = np.dot(inverse_errors,Errors_4)
print('Errors_4_new=', Errors_4_new)
Errors_5_new = np.dot(inverse_errors,Errors_5)
print('Errors_5_new=', Errors_5_new)
Errors_6_new = np.dot(inverse_errors,Errors_6)
print('Errors_6_new=', Errors_6_new)
Errors_7_new = np.dot(inverse_errors,Errors_7)
print('Errors_7_new=', Errors_7_new)
# Out:
# Errors_1_new= [[1.52785849e-05]
#  [2.62273490e-05]
#  [1.58350640e-05]
#  [8.76614866e-05]]
# Errors_2_new= [[9.90686665e-06]
#  [1.73859818e-05]
#  [1.07788274e-05]
#  [5.81426772e-05]]
# Errors_3_new= [[9.02048821e-06]
#  [1.57505309e-05]
#  [9.79481511e-06]
#  [5.35168444e-05]]
# Errors_4_new= [[3.40219870e-06]
#  [5.79099221e-06]
#  [3.69611768e-06]
#  [1.97143400e-05]]
# Errors_5_new= [[7.68544911e-06]
#  [1.33746693e-05]
#  [8.20916270e-06]
#  [4.54200182e-05]]
# Errors_6_new= [[1.09329843e-05]
#  [1.89861520e-05]
#  [1.19546902e-05]
#  [6.41333984e-05]]
# Errors_7_new= [[1.00413194e-05]
#  [1.76156157e-05]
#  [1.09205089e-05]
#  [5.91539310e-05]]

# %%
Errors_new_e=[1.52027874e-05,9.85784170e-06,8.97571646e-06,3.38522443e-06,7.64730455e-06,1.08786888e-05,9.99159998e-06]
Errors_new_t=[2.65511437e-05,1.76003937e-05,1.59426408e-05,5.86129297e-06,1.35379876e-05,1.92183497e-05,1.78322693e-05]
Errors_new_m=[1.55605671e-05,1.05917257e-05,9.62473438e-06,3.63184937e-06,8.06671183e-06,1.17469866e-05,1.07309391e-05]
Errors_new_h=[8.76001358e-05,5.81022142e-05,5.34802186e-05,1.97009529e-05,4.53888344e-05,6.40893648e-05,5.91129346e-05]

# %%
lumi = [463.9790,667.5236,486.7641,2246.568,535.9080,450.6000,709.6980]
lumi_all = [4.249604,5.691792,4.454466,16.43293,4.849260,4.276552,6.104764]

# cross section in nb
cross_section_1= Events_1_new/lumi[0]
cross_section_2= Events_2_new/lumi[1]
cross_section_3= Events_3_new/lumi[2]
cross_section_4= Events_4_new/lumi[3]
cross_section_5= Events_5_new/lumi[4]
cross_section_6= Events_6_new/lumi[5]
cross_section_7= Events_7_new/lumi[6]

print('cross_section_1 =', cross_section_1)
print('cross_section_2 =', cross_section_2)
print('cross_section_3 =', cross_section_3)
print('cross_section_4 =', cross_section_4)
print('cross_section_5 =', cross_section_5)
print('cross_section_6 =', cross_section_6)
print('cross_section_7 =', cross_section_7)

cross_section_e=[0.28126728,0.413184,0.65532412,1.03739373,0.8404877,0.51225335,0.37449416]
cross_section_t=[0.35904154,0.54688527,0.84584788,1.23132608,1.0861878,0.6491661,0.49395489]
cross_section_m=[0.33212824,0.54332051,0.85911762,1.35197632,1.06368106,0.67954888,0.49228869]
cross_section_h=[7.46550611,11.59361162,18.78704068,28.34175746,23.85954063,14.28635247,10.58368352]

fig, ax = plt.subplots(2, 2, figsize=(12,7))
fig.tight_layout()

#create subplots
ax[0, 0].scatter(com_energies, cross_section_e, color='purple',marker = '*', label='Electrons')
ax[0, 0].set_xlabel('Center of mass energy')
ax[0, 0].set_ylabel('cross section of electrons')
ax[0, 0].legend()
ax[0, 1].scatter(com_energies, cross_section_t, color='c',marker = 'o', label='Taus')
ax[0, 1].set_xlabel('Center of mass energy')
ax[0, 1].set_ylabel('cross section of taus')
ax[0, 1].legend()
ax[1, 0].scatter(com_energies, cross_section_m, color='y',marker = '+', label='Muons')
ax[1, 0].set_xlabel('Center of mass energy')
ax[1, 0].set_ylabel('cross section of muons')
ax[1, 0].legend()
ax[1, 1].scatter(com_energies, cross_section_h, color='white',marker = 's', label='Hadrons')
ax[1, 1].set_xlabel('Center of mass energy')
ax[1, 1].set_ylabel('cross section of hadrons')
ax[1, 1].legend()
# Out:
# cross_section_1 = [[0.28125851]
#  [0.3589547 ]
#  [0.33214907]
#  [7.46551166]]
# cross_section_2 = [[ 0.41317115]
#  [ 0.54675074]
#  [ 0.5433545 ]
#  [11.59362012]]
# cross_section_3 = [[ 0.65530372]
#  [ 0.84563719]
#  [ 0.85917133]
#  [18.78705392]]
# cross_section_4 = [[ 1.03736117]
#  [ 1.23101199]
#  [ 1.35206065]
#  [28.3417769 ]]
# cross_section_5 = [[ 0.84046154]
#  [ 1.08591977]
#  [ 1.06374764]
#  [23.85955758]]
# cross_section_6 = [[ 0.51223736]
#  [ 0.64900357]
#  [ 0.67959132]
#  [14.28636264]]
# cross_section_7 = [[ 0.37448251]
#  [ 0.49383309]
#  [ 0.49231948]
#  [10.58369122]]

# %%
error_cross_section_e= [0,0,0,0,0,0,0]
error_cross_section_t= [0,0,0,0,0,0,0]
error_cross_section_m= [0,0,0,0,0,0,0]
error_cross_section_h= [0,0,0,0,0,0,0]

for k in range(7):
    error_cross_section_e[k]= (np.sqrt((Errors_new_e[k]/ Events_new_e[k])**2 + (lumi_all[k]/lumi[k])**2))*cross_section_e[k]
    error_cross_section_t[k]= (np.sqrt((Errors_new_t[k]/ Events_new_t[k])**2 + (lumi_all[k]/lumi[k])**2))*cross_section_t[k]
    error_cross_section_m[k]= (np.sqrt((Errors_new_m[k]/ Events_new_m[k])**2 + (lumi_all[k]/lumi[k])**2))*cross_section_m[k]
    error_cross_section_h[k]= (np.sqrt((Errors_new_h[k]/ Events_new_h[k])**2 + (lumi_all[k]/lumi[k])**2))*cross_section_h[k]

print('error_cross_section_e',error_cross_section_e)
print('error_cross_section_t',error_cross_section_t)
print('error_cross_section_m',error_cross_section_m)
print('error_cross_section_h',error_cross_section_h)
# Out:
# error_cross_section_e [0.0025761393473708997, 0.00352310747627299, 0.005996989119644853, 0.007588205007606818, 0.007605304238990973, 0.004861691274913918, 0.003221368055426497]
# error_cross_section_t [0.003288477204315662, 0.004663141804654695, 0.007740506382179395, 0.009006758433225813, 0.009828565819217847, 0.006161102049164934, 0.004248959459021564]
# error_cross_section_m [0.0030419771095302503, 0.0046327460666140624, 0.007861940164245932, 0.009889276544586184, 0.00962490953115443, 0.006449458770274081, 0.004234626943204459]
# error_cross_section_h [0.06837689771994289, 0.09885556985528096, 0.17192359491937467, 0.20731093668972325, 0.21589734804377375, 0.13558883539351319, 0.09103997776563597]

# %%
xs_corrections_hadronic = [2.0, 4.3, 7.7, 10.8, 4.7, -0.2, -1.6]
xs_corrections_leptonic = [0.09, 0.20, 0.36, 0.52, 0.22, -0.01, -0.08]

corrected_cross_section_e= [0,0,0,0,0,0,0]
corrected_cross_section_t= [0,0,0,0,0,0,0]
corrected_cross_section_m= [0,0,0,0,0,0,0]
corrected_cross_section_h= [0,0,0,0,0,0,0]

for k in range(7):
    corrected_cross_section_e[k] = cross_section_e[k] + xs_corrections_leptonic[k]
    corrected_cross_section_t[k] = cross_section_t[k] + xs_corrections_leptonic[k]
    corrected_cross_section_m[k] = cross_section_m[k] + xs_corrections_leptonic[k]
    corrected_cross_section_h[k] = cross_section_h[k] + xs_corrections_hadronic[k]

print('cross section after corrections of electrons',corrected_cross_section_e)
print('cross section after corrections of taus',corrected_cross_section_t)
print('cross section after corrections of muons',corrected_cross_section_m)
print('cross section after corrections of hadrons',corrected_cross_section_h)
# Out:
# cross section after corrections of electrons [0.37126728, 0.613184, 1.0153241199999998, 1.55739373, 1.0604877, 0.50225335, 0.29449416]
# cross section after corrections of taus [0.44904153999999996, 0.7468852699999999, 1.2058478799999999, 1.7513260800000001, 1.3061878, 0.6391661, 0.41395488999999996]
# cross section after corrections of muons [0.42212824000000004, 0.74332051, 1.21911762, 1.87197632, 1.28368106, 0.66954888, 0.41228868999999996]
# cross section after corrections of hadrons [9.46550611, 15.893611620000001, 26.48704068, 39.14175746, 28.55954063, 14.086352470000001, 8.98368352]

# %%
fig, ax = plt.subplots(2, 2, figsize=(12,7))
fig.tight_layout()

#create subplots
#ax[0, 0].scatter(com_energies, corrected_cross_section_e, color='purple',marker = '*', label='Electrons')
ax[0, 0].errorbar(com_energies, corrected_cross_section_e,yerr=error_cross_section_e, color='purple',fmt = '*', label='Electrons')
ax[0, 0].set_xlabel('Center of mass energy')
ax[0, 0].set_ylabel('Corrected cross section of electrons')
ax[0, 0].legend()
#ax[0, 1].scatter(com_energies, corrected_cross_section_t, color='c',marker = 'o', label='Taus')
ax[0, 1].errorbar(com_energies, corrected_cross_section_t,yerr=error_cross_section_t, color='c',fmt = 'o', label='Taus')
ax[0, 1].set_xlabel('Center of mass energy')
ax[0, 1].set_ylabel('Corrected cross section of taus')
ax[0, 1].legend()
#ax[1, 0].scatter(com_energies, corrected_cross_section_m, color='y',marker = '+', label='Muons')
ax[1, 0].errorbar(com_energies, corrected_cross_section_m,yerr=error_cross_section_m, color='y',fmt = '+', label='Muons')
ax[1, 0].set_xlabel('Center of mass energy')
ax[1, 0].set_ylabel('Corrected cross section of muons')
ax[1, 0].legend()
#ax[1, 1].scatter(com_energies, corrected_cross_section_h, color='white',marker = 's', label='Hadrons')
ax[1, 1].errorbar(com_energies, corrected_cross_section_h,yerr=error_cross_section_h, color='white',fmt = 's', label='Hadrons')
ax[1, 1].set_xlabel('Center of mass energy')
ax[1, 1].set_ylabel('Corrected cross section of hadrons')
ax[1, 1].legend()

# %%
def relativistic_breit_wigner(x, mass, width, normalization):
    gamma = np.sqrt(mass ** 2 * (mass ** 2 + width ** 2))
    k = 2.0 * np.sqrt(2) * mass * width * gamma / (np.pi * np.sqrt(mass ** 2 + gamma))
    return normalization * k / ((x ** 2 - mass ** 2) ** 2 + mass ** 2 * width ** 2)


popt_e, pcov_e = curve_fit(relativistic_breit_wigner, com_energies, corrected_cross_section_e,p0=[91,2,2.5]) #,sigma=error_cross_section_e
popt_t, pcov_t = curve_fit(relativistic_breit_wigner, com_energies, corrected_cross_section_t,p0=[91,2,2.5])
popt_m, pcov_m = curve_fit(relativistic_breit_wigner, com_energies, corrected_cross_section_m,p0=[91,2,2.5]) #,sigma=error_cross_section_m,absolute_sigma=True,
popt_h, pcov_h = curve_fit(relativistic_breit_wigner, com_energies, corrected_cross_section_h,p0=[91,2,2.5]) #,sigma=error_cross_section_h,absolute_sigma=True

fig, ax = plt.subplots(2, 2, figsize=(12,7))
fig.tight_layout()

E=np.linspace(86, 96, 1000)

#create subplots
ax[0, 0].scatter(com_energies, corrected_cross_section_e, color='purple',marker = '*', label='Electrons')
ax[0, 0].plot(E, relativistic_breit_wigner(E, *popt_e), 'g--',label='fit: mass=%5.3f, width=%5.3f, normalization=%5.3f' % tuple(popt_e))
ax[0, 0].set_xlabel('Center of mass energy')
ax[0, 0].set_ylabel('Corrected cross section of electrons')
ax[0, 0].legend()
ax[0, 1].scatter(com_energies, corrected_cross_section_t, color='c',marker = 'o', label='Taus')
ax[0, 1].plot(E, relativistic_breit_wigner(E, *popt_t), 'g--',label='fit: mass=%5.3f, width=%5.3f, normalization=%5.3f' % tuple(popt_t))
ax[0, 1].set_xlabel('Center of mass energy')
ax[0, 1].set_ylabel('Corrected cross section of taus')
ax[0, 1].legend()
ax[1, 0].scatter(com_energies, corrected_cross_section_m, color='y',marker = '+', label='Muons')
ax[1, 0].plot(E, relativistic_breit_wigner(E, *popt_m), 'g--',label='fit: mass=%5.3f, width=%5.3f, normalization=%5.3f' % tuple(popt_m))
ax[1, 0].set_xlabel('Center of mass energy')
ax[1, 0].set_ylabel('Corrected cross section of muons')
ax[1, 0].legend()
ax[1, 1].scatter(com_energies, corrected_cross_section_h, color='white',marker = 's', label='Hadrons')
ax[1, 1].plot(E, relativistic_breit_wigner(E, *popt_h), 'g--',label='fit: mass=%5.3f, width=%5.3f, normalization=%5.3f' % tuple(popt_h))
ax[1, 1].set_xlabel('Center of mass energy')
ax[1, 1].set_ylabel('Corrected cross section of hadrons')
ax[1, 1].legend()

# %%
# popt = fit parameters 
# pcov = covariance of parameters 

Mz_literature = 91.1876
Mz_l_error = 0.0021

# Mass Z boson 

Mz=(popt_e[0]+popt_t[0]+popt_m[0]+popt_h[0])/4

Mz_c_error=np.sqrt(pcov_e[0][0]**2+pcov_t[0][0]**2+pcov_m[0][0]**2+pcov_h[0][0]**2)/4

print('Mass Z boson =', Mz)
print('Mass Z boson error = ', Mz_c_error)

#Width

Width_literature = 2.4952
Width_l_error = 0.0023

Width_e = 2.598
Width_t = 2.870
Width_m = 2.698
Width_h = 2.787

print('Width_e_error',pcov_e[1][0])
print('Width_t_error',pcov_t[1][0])
print('Width_m_error',pcov_m[1][0])
print('Width_h_error',pcov_h[1][0])

#Electrons 

#gammae = np.sqrt(normalization*((Mz**2))/12*np.pi)
Gammae = np.sqrt((6.306*(Mz**2))/12*np.pi)
print('Gammae =', Gammae)

# Others
Gammaf_t = (7.845*(Mz**2))/(12*np.pi*Gammae)
print('Gammaf_t =', Gammaf_t)
Gammaf_m = (7.793*(Mz**2))/(12*np.pi*Gammae)
print('Gammaf_m =', Gammaf_m)
Gammaf_h = (170.011*(Mz**2))/(12*np.pi*Gammae)
print('Gammaf_h =' ,Gammaf_h)

Width_literature = 2.4952
Width_l_error = 0.0023
# Out:
# Mass Z boson = 91.13887933528841
# Mass Z boson error =  0.00040714322260631554
# Width_e_error 0.0004329102192379136
# Width_t_error 0.00020224786610700655
# Width_m_error 0.00040113519201306956
# Width_h_error 0.00015795349019273667
# Gammae = 117.10218014931306
# Gammaf_t = 14.760606980041265
# Gammaf_m = 14.662767392665595
# Gammaf_h = 319.88088633317983

# %% [markdown]
# ### Forward-backward asymmetry

# %%
path_data = 'Data/'
#path_mc = 'samples/data'

### Open the file introducing file path
file = uproot.open(path_data+'mm.root')
ttree_name = 'myTTree'

### Print list of 'branches' of the TTree (i.e. list of variable names)
file[ttree_name].keys()

## Load branches
branches_m = file[ttree_name].arrays()

## Define an numpy array for 'Pcharged'
var10 = 'cos_thet'
cos_et_m = ak.to_numpy(branches_m[var10]) # See Docu (https://awkward-array.org/how-to-convert-numpy.html) for more conversions

print(f"Array of type '{type(cos_et_m)}' defined for '{var10}':\n{cos_et_m}")
print(cos_et_m.max())

plt.style.use('ggplot') 
plt.rcParams['figure.figsize'] = [7, 5]

plt.hist(cos_et_m, bins=50, range=(-1,1), edgecolor='k', color='y', lw=1, label='Muon')
            
#plt.xlim(0.,40.)
plt.xlabel('cos_thet')
plt.ylabel('Ne')
#plt.title('Ncharged')
plt.legend()
plt.show()
# Out:
# Array of type '<class 'numpy.ndarray'>' defined for 'cos_thet':
# [-0.56434125  0.902914   -0.28037506 ... -0.77348113 -0.24306357
#   0.80955154]
# 999.0

# %%
def Count_cos_mc(cos_et_m): 
    Muons_neg=0
    Muons_pos=0
    for i in range(0,len(nchar_m)):
        if cos_et_m[i]<=0:
            Muons_neg+=1
        elif cos_et_m[i]>=0:
            Muons_pos+=1
    return np.array([Muons_neg, Muons_pos])

Muons_neg,Muons_pos = Count_cos_mc(cos_et_m)

print('Backward =', Muons_neg)
print('Forward =', Muons_pos)

AFB_mc = (Muons_pos-Muons_neg)/(Muons_pos+Muons_neg)

print('AFB_mc =', AFB_mc)
# Out:
# Backward = 44709
# Forward = 49672
# AFB_mc = 0.052584736334643625

# %%
# error calculation

#AFB_mc_error = 2/((np.sqrt(Muons_pos)+np.sqrt(Muons_neg))** 2)*np.sqrt(np.sqrt(Muons_pos)** 2*np.sqrt(Muons_neg)+Muons_neg**2*np.sqrt(Muons_pos))
#print('AFB_mc_error =', AFB_mc_error)

radiation_corrections = [0.021512, 0.019262, 0.016713, 0.018293, 0.030286, 0.062196, 0.093850]

AFB_mc_corrected = AFB_mc + radiation_corrections[4]
print('AFB_mc_corrected =', AFB_mc_corrected)

# Weinberg Angle

sin_AngleW_mc = (1-np.sqrt(AFB_mc/3))/4

print('sin_AngleW_mc =', sin_AngleW_mc )
# Out:
# AFB_mc_corrected = 0.08287073633464362
# sin_AngleW_mc = 0.2169014299356441

# %%
def Count_cos_data(E_l,E_e,nchar,E_h,pchar): 
    Muons=0
    #costheta values for muons in resonance energy
    cos_thet_muon=[]
    
    Muons_neg=0
    Muons_pos=0
    
    for i in range(0,len(nchar_m)):
        if E_l[i]>=45.5 and E_l[i]<=45.7 and E_e[i]<=15 and nchar[i]<=6 and E_h[i]<=15 and pchar[i]>=60:
            Muons+=1
            cos_thet_muon.append(cos_et_m[i])
            
            if cos_et_m[i]<=0:
                Muons_neg+=1
            elif cos_et_m[i]>=0:
                Muons_pos+=1
    return (Muons,cos_thet_muon, Muons_neg, Muons_pos)

Muons, cos_thet_muon,Muons_neg, Muons_pos = Count_cos_data(E_l,E_e,nchar,E_h,pchar)

print('Events_muons =', Muons)
print('Backward =', Muons_neg)
print('Forward =', Muons_pos)

AFB_data = (Muons_pos-Muons_neg)/(Muons_pos+Muons_neg)

print('AFB_data =', AFB_data)

plt.style.use('ggplot') 
plt.rcParams['figure.figsize'] = [7, 5]

plt.hist(cos_thet_muon, bins=50, range=(-1,1), edgecolor='k', color='y', lw=1, label='Muon')
#plt.xlim(0.,40.)
plt.xlabel('cos_thet')
plt.ylabel('Nμ')
plt.title('cosθ muons')
plt.legend()
plt.show()
# Out:
# Events_muons = 2385
# Backward = 1144
# Forward = 1241
# AFB_data = 0.04067085953878407

# %%
# error calculation

#AFB_data_error = 2/((np.sqrt(Muons_pos)+np.sqrt(Muons_neg))** 2)*np.sqrt(np.sqrt(Muons_pos)** 2*np.sqrt(Muons_neg)+Muons_neg**2*np.sqrt(Muons_pos))
#print('AFB_data_error =', AFB_data_error)

radiation_corrections = [0.021512, 0.019262, 0.016713, 0.018293, 0.030286, 0.062196, 0.093850]

AFB_data_corrected = [0,0,0,0,0,0,0]

for k in range(7):
    AFB_data_corrected[k] = AFB_data + radiation_corrections[k]

print('AFB_data_corrected =', AFB_data_corrected)

# Weinberg Angle

sin_AngleW_data = (1-np.sqrt(AFB_data/3))/4

print('sin_AngleW_data =', sin_AngleW_data )
# Out:
# AFB_data_corrected = [0.062182859538784066, 0.05993285953878407, 0.05738385953878407, 0.058963859538784066, 0.07095685953878407, 0.10286685953878408, 0.13452085953878407]
# sin_AngleW_data = 0.22089141752464286
