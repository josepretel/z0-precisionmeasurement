# %%
# %pylab inline
# %config InlineBackend.figure_format = 'svg'  # damit kann man plots als Vektorgrafik speichern.
import matplotlib.ticker as ticker  # Für die Formatierung der Gitterlinien.
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)
import csv

# %%
rows = []
with open("data_grope/ELECTRONS.csv", 'r') as file:
    csvreader = csv.reader(file)
    header = next(csvreader)
    for row in csvreader:
        row = [float(i) for i in row]
        rows.append(row)
rows = np.array(rows)
rows_e = rows
rows = []
with open("data_grope/MUONS.csv", 'r') as file:
    csvreader = csv.reader(file)
    header = next(csvreader)
    for row in csvreader:
        row = [float(i) for i in row]
        rows.append(row)
rows = np.array(rows)
rows_mu = rows
rows = []
with open("data_grope/TAUS.csv", 'r') as file:
    csvreader = csv.reader(file)
    header = next(csvreader)
    for row in csvreader:
        row = [float(i) for i in row]
        rows.append(row)
rows = np.array(rows)
rows_tau = rows
rows = []
with open("data_grope/HADRONS.csv", 'r') as file:
    csvreader = csv.reader(file)
    header = next(csvreader)
    for row in csvreader:
        row = [float(i) for i in row]
        rows.append(row)
rows = np.array(rows)
rows_had = rows

rows = {'electrons': rows_e, 
        'muons': rows_mu,
        'tauons': rows_tau,
        'hadrons': rows_had} 

for items in rows:
    print(min(rows[items][:,5]))
    print(max(rows[items][:,5]))

# %%
for items in rows:
    for n in range(2,len(rows[items][0])-1):
        ax = plt.axes()
        ax.yaxis.set_major_locator(ticker.MultipleLocator(1))
        ax.xaxis.set_minor_locator(AutoMinorLocator())

        plt.grid(axis='y', which='major', color='black', linestyle='-', alpha=0.5)
        
        plt.xlabel('Energy in GeV')

        if n == 2:
            plt.gca().set_xlim(-1, 301)  # Limits für die x-Achse.
            _ = plt.hist(rows[items][:,n], bins=15, range=(0, 300), rwidth=0.99, alpha=1, color='#396ab1')
            plt.title(items + ' - momentum of charged tracks')
        elif n == 3:
            ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
            plt.gca().set_xlim(-1, 56)  # Limits für die x-Achse.
            _ = plt.hist(rows[items][:,n], bins=11, range=(0, 55), rwidth=0.99, alpha=1, color='#396ab1')
            plt.xlabel('Amount of charged tracks')
            plt.title(items + ' - numbers of charged tracks')
        elif n == 4:
            plt.gca().set_xlim(-1, 101)  # Limits für die x-Achse.
            _ = plt.hist(rows[items][:,n], bins=20, range=(0, 100), rwidth=0.99, alpha=1, color='#396ab1')
            plt.title(items + ' - total energy in the electromagnetic calorimeter')
        elif n == 5:
            ax.xaxis.set_major_locator(ticker.MultipleLocator(20))
            plt.gca().set_xlim(-1, 211)  # Limits für die x-Achse.
            _ = plt.hist(rows[items][:,n], bins=21, range=(0, 210), rwidth=0.99, alpha=1, color='#396ab1')
            plt.title(items + ' - total energy in the hadronic calorimeter')
            
        #elif n == 5:
        #    plt.gca().set_xlim(-1, 4)  # Limits für die x-Achse.
        #    _ = plt.hist(rows[items][:,n], bins='auto', range=(0, 3), rwidth=0.99, alpha=1, color='#396ab1')
            
        plt.ylabel('count')
        #plt.savefig(items + str(n-2) + ".pdf", bbox_inches='tight')
        plt.show()

# %%
colors = {'electrons': '#396ab1', 
        'muons': '#cc2529',
        'tauons': '#3e9651',
        'hadrons': '#da7c30'} 
for n in range(2,len(rows[items][0])-1):
    ax = plt.axes()
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.xaxis.set_minor_locator(AutoMinorLocator())

    plt.grid(axis='y', which='major', color='black', linestyle='-', alpha=0.5)

    plt.xlabel('Energy in GeV')
    plt.ylabel('count')
    for items in rows:
        if n == 2:
            plt.gca().set_xlim(-1, 301)  # Limits für die x-Achse.
            _ = plt.hist(rows[items][:,n], bins=15, range=(0, 300), rwidth=0.99, alpha=0.6, color=colors[items], label=items)
            plt.title('overlay - momentum of charged tracks')

        if n == 3:
            ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
            plt.gca().set_xlim(-1, 56)  # Limits für die x-Achse.
            _ = plt.hist(rows[items][:,n], bins=11, range=(0, 55), rwidth=0.99, alpha=0.6, color=colors[items], label=items)
            plt.xlabel('Amount of charged tracks')
            plt.title('overlay - numbers of charged tracks')

        if n == 4:
            plt.gca().set_xlim(-1, 101)  # Limits für die x-Achse.
            _ = plt.hist(rows[items][:,n], bins=20, range=(0, 100), rwidth=0.99, alpha=0.6, color=colors[items], label=items)
            plt.title('overlay - total energy in the electromagnetic calorimeter')

        if n == 5:
            ax.xaxis.set_major_locator(ticker.MultipleLocator(20))
            plt.gca().set_xlim(-1, 211)  # Limits für die x-Achse.
            _ = plt.hist(rows[items][:,n], bins=21, range=(0, 210), rwidth=0.99, alpha=0.6, color=colors[items], label=items)
            plt.title('overlay - total energy in the hadronic calorimeter')
    plt.legend()
    #plt.savefig('overlay' + str(n-2) + '.pdf', bbox_inches='tight')
    plt.show()
